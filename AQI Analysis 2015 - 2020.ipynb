# %% [markdown]
# # Air Quality Data in India (2015 - 2020)
# ![](https://carbontracker.org/wp-content/uploads/2019/08/air-pollution-chimney-clouds-459728.jpg)

# %% [markdown]
# ### Air quality index
# - The air quality index **(AQI)** is an index for reporting **air quality** on a daily basis. It is a measure of how air
#   pollution   **affects** one's health within a short time period.
# - So, Let's get started with the analysis.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
city_df = pd.read_csv(r"city_day.csv")
city_df.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
city_df.tail()
# Out:
#                 City        Date  PM2.5   PM10    NO    NO2    NOx    NH3  \
# 29526  Visakhapatnam  2020-06-27  15.02  50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97  4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00  0.40  26.85  14.05   5.20
#
#          CO    SO2     O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 29526  0.47   8.55  23.30     2.24    12.07    0.73  41.0          Good
# 29527  0.52  12.72  30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528  0.48   8.42  30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529  0.52   9.84  28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530  0.59   2.10  17.05      NaN      NaN     NaN  50.0          Good

# %%
# Get info of data types of columns.
city_df['Date'] = city_df['Date'].apply(pd.to_datetime) # Changing data type of 'Date' column from object to date time.
city_df.dtypes
# Out:
# City                  object
# Date          datetime64[ns]
# PM2.5                float64
# PM10                 float64
# NO                   float64
# NO2                  float64
# NOx                  float64
# NH3                  float64
# CO                   float64
# SO2                  float64
# O3                   float64
# Benzene              float64
# Toluene              float64
# Xylene               float64
# AQI                  float64
# AQI_Bucket            object
# dtype: object

# %%
# Checking for missing values

missing_data = city_df.isnull().sum()
percent_missing = (missing_data/len(city_df))*100
data_frame = pd.concat([missing_data,percent_missing.round(2)],axis=1)
data_frame.columns = ['No of missing values','% of missing values']
data_frame.sort_values('% of missing values',ascending=False).style.background_gradient('Blues')
# Out:
# <style type="text/css">
# #T_ae6f3_row0_col0, #T_ae6f3_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ae6f3_row1_col0, #T_ae6f3_row1_col1 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_ae6f3_row2_col0 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_ae6f3_row2_col1 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_ae6f3_row3_col0, #T_ae6f3_row3_col1 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_ae6f3_row4_col0, #T_ae6f3_row4_col1 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_ae6f3_row5_col0, #T_ae6f3_row5_col1, #T_ae6f3_row6_col0, #T_ae6f3_row6_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_ae6f3_row7_col0, #T_ae6f3_row7_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_ae6f3_row8_col0, #T_ae6f3_row8_col1 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_ae6f3_row9_col0, #T_ae6f3_row9_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_ae6f3_row10_col0, #T_ae6f3_row10_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_ae6f3_row11_col0, #T_ae6f3_row11_col1, #T_ae6f3_row12_col0, #T_ae6f3_row12_col1 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_ae6f3_row13_col0, #T_ae6f3_row13_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_ae6f3_row14_col0, #T_ae6f3_row14_col1, #T_ae6f3_row15_col0, #T_ae6f3_row15_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_ae6f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae6f3_level0_col0" class="col_heading level0 col0" >No of missing values</th>
#       <th id="T_ae6f3_level0_col1" class="col_heading level0 col1" >% of missing values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae6f3_level0_row0" class="row_heading level0 row0" >Xylene</th>
#       <td id="T_ae6f3_row0_col0" class="data row0 col0" >18109</td>
#       <td id="T_ae6f3_row0_col1" class="data row0 col1" >61.320000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row1" class="row_heading level0 row1" >PM10</th>
#       <td id="T_ae6f3_row1_col0" class="data row1 col0" >11140</td>
#       <td id="T_ae6f3_row1_col1" class="data row1 col1" >37.720000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row2" class="row_heading level0 row2" >NH3</th>
#       <td id="T_ae6f3_row2_col0" class="data row2 col0" >10328</td>
#       <td id="T_ae6f3_row2_col1" class="data row2 col1" >34.970000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row3" class="row_heading level0 row3" >Toluene</th>
#       <td id="T_ae6f3_row3_col0" class="data row3 col0" >8041</td>
#       <td id="T_ae6f3_row3_col1" class="data row3 col1" >27.230000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row4" class="row_heading level0 row4" >Benzene</th>
#       <td id="T_ae6f3_row4_col0" class="data row4 col0" >5623</td>
#       <td id="T_ae6f3_row4_col1" class="data row4 col1" >19.040000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row5" class="row_heading level0 row5" >AQI</th>
#       <td id="T_ae6f3_row5_col0" class="data row5 col0" >4681</td>
#       <td id="T_ae6f3_row5_col1" class="data row5 col1" >15.850000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row6" class="row_heading level0 row6" >AQI_Bucket</th>
#       <td id="T_ae6f3_row6_col0" class="data row6 col0" >4681</td>
#       <td id="T_ae6f3_row6_col1" class="data row6 col1" >15.850000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row7" class="row_heading level0 row7" >PM2.5</th>
#       <td id="T_ae6f3_row7_col0" class="data row7 col0" >4598</td>
#       <td id="T_ae6f3_row7_col1" class="data row7 col1" >15.570000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row8" class="row_heading level0 row8" >NOx</th>
#       <td id="T_ae6f3_row8_col0" class="data row8 col0" >4185</td>
#       <td id="T_ae6f3_row8_col1" class="data row8 col1" >14.170000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row9" class="row_heading level0 row9" >O3</th>
#       <td id="T_ae6f3_row9_col0" class="data row9 col0" >4022</td>
#       <td id="T_ae6f3_row9_col1" class="data row9 col1" >13.620000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row10" class="row_heading level0 row10" >SO2</th>
#       <td id="T_ae6f3_row10_col0" class="data row10 col0" >3854</td>
#       <td id="T_ae6f3_row10_col1" class="data row10 col1" >13.050000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row11" class="row_heading level0 row11" >NO2</th>
#       <td id="T_ae6f3_row11_col0" class="data row11 col0" >3585</td>
#       <td id="T_ae6f3_row11_col1" class="data row11 col1" >12.140000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row12" class="row_heading level0 row12" >NO</th>
#       <td id="T_ae6f3_row12_col0" class="data row12 col0" >3582</td>
#       <td id="T_ae6f3_row12_col1" class="data row12 col1" >12.130000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row13" class="row_heading level0 row13" >CO</th>
#       <td id="T_ae6f3_row13_col0" class="data row13 col0" >2059</td>
#       <td id="T_ae6f3_row13_col1" class="data row13 col1" >6.970000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row14" class="row_heading level0 row14" >City</th>
#       <td id="T_ae6f3_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_ae6f3_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f3_level0_row15" class="row_heading level0 row15" >Date</th>
#       <td id="T_ae6f3_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_ae6f3_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Calculate AQI
# - Since our data set has missing **AQI** values. Although we have information of all essential pollutants.Thus, we need to
#   calculate these AQI values.
# - Note for calculating **final** AQI we need data for either PM2.5 or PM10, Also data for any three Pollutants from all
#   pollutants.
# - For more information please refer given link [Kaggle](https://www.kaggle.com/rohanrao/calculating-aqi-air-quality-index-tutorial)

# %%
# Delete rows with PM2.5 and PM10 both null.
city_df.dropna(axis=0, how="all", subset=['PM2.5','PM10'], inplace = True)
city_df.head()
# Out:
#          City       Date   PM2.5  PM10     NO    NO2    NOx  NH3     CO  \
# 27  Ahmedabad 2015-01-28   73.24   NaN   5.72  21.11  25.84  NaN   5.72
# 28  Ahmedabad 2015-01-29   83.13   NaN   6.93  28.71  33.72  NaN   6.93
# 29  Ahmedabad 2015-01-30   79.84   NaN  13.85  28.68  41.08  NaN  13.85
# 30  Ahmedabad 2015-01-31   94.52   NaN  24.39  32.66  52.61  NaN  24.39
# 31  Ahmedabad 2015-02-01  135.99   NaN  43.48  42.08  84.57  NaN  43.48
#
#       SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 27  36.52   62.42     0.03     0.01    1.41    NaN        NaN
# 28  49.52   59.76     0.02     0.00    3.14  209.0       Poor
# 29  48.49   97.07     0.04     0.00    4.81  328.0  Very Poor
# 30  67.39  111.33     0.24     0.01    7.67  514.0     Severe
# 31  75.23  102.70     0.40     0.04   25.87  782.0     Severe

# %% [markdown]
# #### Code to store current data frame into .csv file in local machine
# ```
# # Store this data frame to csv file in local machine.
# city_df.to_csv("file address")
#
# # Now rest calculations of AQI we shall do in excel.
# ```

# %% [markdown]
# ### Use AQI calculated and cleaned data set
# - **MS-excel** is used to calculate sub-index, AQI, and AQI_Bucket columns.

# %%
city_cleaned_df = pd.read_csv("City_data_cleaned.csv")
city_cleaned_df.head()
# Out:
#         City        Date   PM2.5  PM10     NO    NO2    NOx  NH3     CO  \
# 0  Ahmedabad  28-01-2015   73.24   NaN   5.72  21.11  25.84  NaN   5.72
# 1  Ahmedabad  29-01-2015   83.13   NaN   6.93  28.71  33.72  NaN   6.93
# 2  Ahmedabad  30-01-2015   79.84   NaN  13.85  28.68  41.08  NaN  13.85
# 3  Ahmedabad  31-01-2015   94.52   NaN  24.39  32.66  52.61  NaN  24.39
# 4  Ahmedabad  01-02-2015  135.99   NaN  43.48  42.08  84.57  NaN  43.48
#
#      SO2  ...  Xylene  PM2.5 (Subindex)  PM10 (Sub index)  NOx (Sub index)  \
# 0  36.52  ...    1.41             144.0               0.0             32.0
# 1  49.52  ...    3.14             177.0               0.0             42.0
# 2  48.49  ...    4.81             166.0               0.0           -399.0
# 3  67.39  ...    7.67             215.0               0.0           -384.0
# 4  75.23  ...   25.87             312.0               0.0            105.0
#
#    NH3 (Sub index)  CO (Sub index)  SO2 (Sub index)  O3 (Sub index)    AQI  \
# 0              0.0           147.0             46.0            62.0  147.0
# 1              0.0           162.0             62.0            60.0  209.0
# 2              0.0           255.0             61.0            97.0  328.0
# 3              0.0           343.0             84.0           117.0  514.0
# 4              0.0           456.0             94.0           104.0  782.0
#
#    AQI_Bucket
# 0    Moderate
# 1        Poor
# 2   Very Poor
# 3      Severe
# 4      Severe
#
# [5 rows x 23 columns]

# %%
# Create pivot table for Understanding the type of pollution in cities. 
pivot_df = city_cleaned_df.pivot_table(index = ['AQI_Bucket'], columns = ['City'],aggfunc = 'mean')['AQI'].round(1)
pivot_df.head()
# Out:
# City          Ahmedabad  Aizawl  Amaravati  Amritsar  Bengaluru  Bhopal  \
# AQI_Bucket
# Good               48.0    24.5       41.2      42.2       41.5    43.0
# Moderate          155.0     NaN      137.0     132.9      128.5   133.5
# Poor              245.1   267.0      237.2     244.0      233.5   242.5
# Satisfactory       87.3    65.2       73.1      76.7       75.0    79.6
# Severe            682.0     NaN      464.2     637.1        NaN     NaN
#
# City          Brajrajnagar  Chandigarh  Chennai  Coimbatore  ...  Jorapokhar  \
# AQI_Bucket                                                   ...
# Good                  36.9        40.1     44.8        40.4  ...        40.0
# Moderate             130.6       126.0    136.6       106.9  ...       136.2
# Poor                 249.1       244.6    229.6         NaN  ...       240.8
# Satisfactory          84.3        76.1     78.3        75.8  ...        83.5
# Severe               544.5         NaN    434.5         NaN  ...       523.6
#
# City          Kochi  Kolkata  Lucknow  Mumbai  Patna  Shillong  Talcher  \
# AQI_Bucket
# Good            NaN     42.9     45.4    47.4    NaN      34.4     27.4
# Moderate      125.0    144.4    144.7   141.7  143.8     126.2    132.4
# Poor          245.3    248.2    245.1   225.9  243.9       NaN    249.7
# Satisfactory   81.4     71.8     79.3    74.3   84.2      70.7     82.8
# Severe          NaN    424.8    454.2     NaN  448.0     869.0    458.9
#
# City          Thiruvananthapuram  Visakhapatnam
# AQI_Bucket
# Good                        45.0           43.4
# Moderate                   126.4          128.9
# Poor                       217.2          250.4
# Satisfactory                70.2           79.7
# Severe                       NaN            NaN
#
# [5 rows x 26 columns]

# %%
pivot_df.replace(np.nan,0,inplace=True)
pivot_df
# Out:
# City          Ahmedabad  Aizawl  Amaravati  Amritsar  Bengaluru  Bhopal  \
# AQI_Bucket
# Good               48.0    24.5       41.2      42.2       41.5    43.0
# Moderate          155.0     0.0      137.0     132.9      128.5   133.5
# Poor              245.1   267.0      237.2     244.0      233.5   242.5
# Satisfactory       87.3    65.2       73.1      76.7       75.0    79.6
# Severe            682.0     0.0      464.2     637.1        0.0     0.0
# Very Poor         343.4   399.0      327.2     322.7      329.2   308.5
#
# City          Brajrajnagar  Chandigarh  Chennai  Coimbatore  ...  Jorapokhar  \
# AQI_Bucket                                                   ...
# Good                  36.9        40.1     44.8        40.4  ...        40.0
# Moderate             130.6       126.0    136.6       106.9  ...       136.2
# Poor                 249.1       244.6    229.6         0.0  ...       240.8
# Satisfactory          84.3        76.1     78.3        75.8  ...        83.5
# Severe               544.5         0.0    434.5         0.0  ...       523.6
# Very Poor            318.1       321.3    338.7         0.0  ...       339.8
#
# City          Kochi  Kolkata  Lucknow  Mumbai  Patna  Shillong  Talcher  \
# AQI_Bucket
# Good            0.0     42.9     45.4    47.4    0.0      34.4     27.4
# Moderate      125.0    144.4    144.7   141.7  143.8     126.2    132.4
# Poor          245.3    248.2    245.1   225.9  243.9       0.0    249.7
# Satisfactory   81.4     71.8     79.3    74.3   84.2      70.7     82.8
# Severe          0.0    424.8    454.2     0.0  448.0     869.0    458.9
# Very Poor       0.0    353.1    344.8   307.0  345.5       0.0    339.8
#
# City          Thiruvananthapuram  Visakhapatnam
# AQI_Bucket
# Good                        45.0           43.4
# Moderate                   126.4          128.9
# Poor                       217.2          250.4
# Satisfactory                70.2           79.7
# Severe                       0.0            0.0
# Very Poor                    0.0          318.8
#
# [6 rows x 26 columns]

# %% [markdown]
# ## Status of pollution over 5 years
# - The below plot shows average pollution over five years was either
#   - Good
#   - Moderate
#   - Satisfactory
#   - Poor
#   - Very Poor
#   - Severe

# %%
plt.subplots(figsize=(15,15))
plt.xlabel('Cities', size = 15)
plt.ylabel('AQI_Bucket', size = 15)
plt.title('Level of pollution', size = 15)
sns.heatmap(pivot_df,cmap='Reds',annot=True, fmt=".1f",linewidths=.5,square = True,cbar = False);
plt.show()

# %% [markdown]
# ## Top 3 Cities using bar plot

# %%
plt.subplots(figsize=(13,13))
ax = city_cleaned_df.groupby('City')['AQI'].mean().sort_values()
ax.plot(kind='barh')
plt.title('Average AQI from 2015-2020',size=15)
plt.xlabel('Average AQI',size=15)
plt.ylabel('City',size=15)
# Out:
# Text(0, 0.5, 'City')

# %% [markdown]
# ## Correlation of data set

# %%
city_df = city_cleaned_df.copy()
city_df['BTX'] = city_cleaned_df['Benzene']+city_cleaned_df['Toluene']+city_cleaned_df['Xylene']
city_df['Particulate_Matter'] = city_cleaned_df['PM2.5']+city_cleaned_df['PM10']
city_df['Nitrogen Oxides'] = city_cleaned_df['NO']+city_cleaned_df['NO2']+city_cleaned_df['NOx']
city_df.drop(['Benzene','Toluene','Xylene','PM2.5','PM10','NO','NO2','NOx','PM2.5 (Subindex)','PM10 (Sub index)','NOx (Sub index)','NH3 (Sub index)','CO (Sub index)','SO2 (Sub index)','O3 (Sub index)'],axis=1,inplace=True)

plt.figure(figsize=(7,5))
sns.heatmap(city_df.corr(),cmap='YlGnBu',annot=True);
plt.title('Correlation heatmap',size=15)
# Out:
# Text(0.5, 1.0, 'Correlation heatmap')

# %% [markdown]
# The reason for AQI increase in the cities is due **Nitrogen Oxides**, **Particulate matter**, and **Co** pollutants.

# %% [markdown]
# ## Analysis report
# - The top city to invest in is Ahmedabad, followed by Delhi and Patna.
# - The main gases or pollutants responsible for high AQI count are **NO, Particulate matter, and CO**.
# - Also to reduce pollution measure should be taken to restrict the modes causing increase in the above pollutants.
